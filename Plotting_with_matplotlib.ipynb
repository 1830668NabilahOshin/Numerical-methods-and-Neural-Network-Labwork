# %% [markdown]
# <a href="https://colab.research.google.com/github/1830668NabilahOshin/Numerical-methods-and-Neural-Network-Labwork/blob/main/Plotting_with_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x1= np.arange(-5, 5, 0.5)

x2= np.arange(-5, 5, 0.5)
x1, x2 = np.meshgrid(x1, x2)
f= (x1*x1) + (3*x2)




fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x1, x2, f,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot 1')
plt.show()
